# %%
import pymongo
import json
import os
import pandas as pd
import sys
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
import pickle

# %%
# import the connecting credentials 
sys.path.append('../')
from secret import credentials
sys.path.remove('../')

# %%
## mongo API connection
sec = credentials()
mongo_uri = sec.connect_string

myclient = pymongo.MongoClient(mongo_uri)

# %%
print(myclient.list_database_names())
# Out:
# ['bookdb', 'admin', 'local']

# %%
mydb = myclient['bookdb']
col_books = mydb['books']
col_ratings = mydb['ratings']
col_users = mydb['users']

# %%
# Query the data (this example retrieves all documents in the collection)
data = list(col_books.find({}))
# Convert the data to a Pandas DataFrame
books = pd.DataFrame(data)

# Query the data (this example retrieves all documents in the collection)
data = list(col_ratings.find({}))
# Convert the data to a Pandas DataFrame
ratings = pd.DataFrame(data)

# Query the data (this example retrieves all documents in the collection)
data = list(col_users.find({}))
# Convert the data to a Pandas DataFrame
users = pd.DataFrame(data)

# %%
books.drop('_id', axis=1, inplace= True)
ratings.drop('_id', axis=1, inplace= True)
users.drop('_id', axis=1, inplace= True)

# %% [markdown]
# ## Data Preprocessing

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
# select the columns that needed 
books = books[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
       'Image-URL-L']]

# %%
# rename the columns
books.rename(columns={
    'Book-Title':'title',
    'Book-Author':'author',
    'Year-Of-Publication':'year',
    'Image-URL-L':'Image_URL'
}, inplace=True)

# %%
books.head()
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  author  year                   Publisher  \
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
#
#                                            Image_URL
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
ratings.rename(columns={
    'User-ID': 'user_id',
    'Book-Rating': 'rating'
}, inplace=True)

# %%
ratings.head()
# Out:
#    user_id        ISBN  rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6

# %%
users.rename(columns={
    'User-ID':'user_id'
}, inplace=True)

# %%
users.head()
# Out:
#    user_id                            Location         country         city  \
# 0      1.0                  nyc, new york, usa             usa          nyc
# 1      2.0           stockton, california, usa             usa     stockton
# 2      3.0     moscow, yukon territory, russia          russia       moscow
# 3      4.0           porto, v.n.gaia, portugal        portugal        porto
# 4      5.0  farnborough, hants, united kingdom  united kingdom  farnborough
#
#     Age
# 0   NaN
# 1  18.0
# 2   NaN
# 3  17.0
# 4   NaN

# %% [markdown]
# ## Data Cleaning

# %%
ratings['user_id'].value_counts()
# Out:
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: user_id, Length: 105283, dtype: int64

# %%
# we are select users rating more than 200 books
# create a flieter 

flit = ratings['user_id'].value_counts() > 200

# %%
flit_index = flit[flit].index

# %%
ratings = ratings[ratings['user_id'].isin(flit_index)]

# %%
# new ratings after flitering
ratings
# Out:
#          user_id        ISBN  rating
# 1456      277427  002542730X      10
# 1457      277427  0026217457       0
# 1458      277427  003008685X       8
# 1459      277427  0030615321       0
# 1460      277427  0060002050       0
# ...          ...         ...     ...
# 1147612   275970  3829021860       0
# 1147613   275970  4770019572       0
# 1147614   275970   896086097       0
# 1147615   275970  9626340762       8
# 1147616   275970  9626344990       0
#
# [526356 rows x 3 columns]

# %%
###################filter########## 30 books

# %%
ratings['ISBN'].value_counts()
# Out:
# 0971880107    363
# 0316666343    270
# 0060928336    220
# 0440214041    218
# 0385504209    215
#              ...
# 0451211170      1
# 0451211073      1
# 0451210484      1
# 0451210476      1
# 9626344990      1
# Name: ISBN, Length: 207291, dtype: int64

# %%
# Flieter rating, select num of rating greater than 30
flit = ratings['ISBN'].value_counts() > 30

# %%
flit_index = flit[flit].index

# %%
ratings = ratings[ratings['ISBN'].isin(flit_index)]

# %%
# new ratings after flitering
ratings
# Out:
#          user_id        ISBN  rating
# 1456      277427  002542730X      10
# 1468      277427  006092988X       0
# 1469      277427  0060930535       0
# 1471      277427  0060934417       0
# 1474      277427  0061009059       9
# ...          ...         ...     ...
# 1147439   275970  1400031346       0
# 1147440   275970  1400031354       0
# 1147441   275970  1400031362       0
# 1147470   275970  1558744606       0
# 1147517   275970  1573229725       0
#
# [72439 rows x 3 columns]

# %%
# merge ratings and books
ratings_with_books = ratings.merge(books, on='ISBN', how='inner')

# %%
ratings_with_books
# Out:
#        user_id        ISBN  rating  \
# 0       277427  002542730X      10
# 1         3363  002542730X       0
# 2        11676  002542730X       6
# 3        12538  002542730X      10
# 4        13552  002542730X       0
# ...        ...         ...     ...
# 72218   235935  0451180216       0
# 72219   238545  0451180216       0
# 72220   241666  0451180216       0
# 72221   242106  0451180216       0
# 72222   274308  0451180216       0
#
#                                                    title  \
# 0      Politically Correct Bedtime Stories: Modern Ta...
# 1      Politically Correct Bedtime Stories: Modern Ta...
# 2      Politically Correct Bedtime Stories: Modern Ta...
# 3      Politically Correct Bedtime Stories: Modern Ta...
# 4      Politically Correct Bedtime Stories: Modern Ta...
# ...                                                  ...
# 72218                                Interest of Justice
# 72219                                Interest of Justice
# 72220                                Interest of Justice
# 72221                                Interest of Justice
# 72222                                Interest of Justice
#
#                        author  year                  Publisher  \
# 0           James Finn Garner  1994  John Wiley &amp; Sons Inc
# 1           James Finn Garner  1994  John Wiley &amp; Sons Inc
# 2           James Finn Garner  1994  John Wiley &amp; Sons Inc
# 3           James Finn Garner  1994  John Wiley &amp; Sons Inc
# 4           James Finn Garner  1994  John Wiley &amp; Sons Inc
# ...                       ...   ...                        ...
# 72218  Nancy Taylor Rosenberg  1994                Signet Book
# 72219  Nancy Taylor Rosenberg  1994                Signet Book
# 72220  Nancy Taylor Rosenberg  1994                Signet Book
# 72221  Nancy Taylor Rosenberg  1994                Signet Book
# 72222  Nancy Taylor Rosenberg  1994                Signet Book
#
#                                                Image_URL
# 0      http://images.amazon.com/images/P/002542730X.0...
# 1      http://images.amazon.com/images/P/002542730X.0...
# 2      http://images.amazon.com/images/P/002542730X.0...
# 3      http://images.amazon.com/images/P/002542730X.0...
# 4      http://images.amazon.com/images/P/002542730X.0...
# ...                                                  ...
# 72218  http://images.amazon.com/images/P/0451180216.0...
# 72219  http://images.amazon.com/images/P/0451180216.0...
# 72220  http://images.amazon.com/images/P/0451180216.0...
# 72221  http://images.amazon.com/images/P/0451180216.0...
# 72222  http://images.amazon.com/images/P/0451180216.0...
#
# [72223 rows x 8 columns]

# %%
raing_countBy_books = ratings_with_books.groupby('title')['rating'].count().reset_index()
raing_countBy_books.head()
# Out:
#                  title  rating
# 0   16 Lighthouse Road      38
# 1                 1984      52
# 2  1st to Die: A Novel     162
# 3    2010: Odyssey Two      43
# 4    204 Rosewood Lane      40

# %%
raing_countBy_books.rename(columns={
    'rating':'num_of_rating'
}, inplace=True)

# %%
raing_countBy_books.head()
# Out:
#                  title  num_of_rating
# 0   16 Lighthouse Road             38
# 1                 1984             52
# 2  1st to Die: A Novel            162
# 3    2010: Odyssey Two             43
# 4    204 Rosewood Lane             40

# %%
final_rating = raing_countBy_books.merge(ratings_with_books, on='title')
final_rating.head()
# Out:
#                 title  num_of_rating  user_id        ISBN  rating  \
# 0  16 Lighthouse Road             38    11676  1551668300       0
# 1  16 Lighthouse Road             38    30276  1551668300       6
# 2  16 Lighthouse Road             38    43842  1551668300       0
# 3  16 Lighthouse Road             38    52614  1551668300       0
# 4  16 Lighthouse Road             38    76352  1551668300       0
#
#             author  year Publisher  \
# 0  Debbie Macomber  2001      Mira
# 1  Debbie Macomber  2001      Mira
# 2  Debbie Macomber  2001      Mira
# 3  Debbie Macomber  2001      Mira
# 4  Debbie Macomber  2001      Mira
#
#                                            Image_URL
# 0  http://images.amazon.com/images/P/1551668300.0...
# 1  http://images.amazon.com/images/P/1551668300.0...
# 2  http://images.amazon.com/images/P/1551668300.0...
# 3  http://images.amazon.com/images/P/1551668300.0...
# 4  http://images.amazon.com/images/P/1551668300.0...

# %%
final_rating.shape
# Out:
# (72223, 9)

# %%
final_rating
# Out:
#                      title  num_of_rating  user_id        ISBN  rating  \
# 0       16 Lighthouse Road             38    11676  1551668300       0
# 1       16 Lighthouse Road             38    30276  1551668300       6
# 2       16 Lighthouse Road             38    43842  1551668300       0
# 3       16 Lighthouse Road             38    52614  1551668300       0
# 4       16 Lighthouse Road             38    76352  1551668300       0
# ...                    ...            ...      ...         ...     ...
# 72218  \O\" Is for Outlaw"            105   234359  0805059555       0
# 72219  \O\" Is for Outlaw"            105   234623  0805059555       0
# 72220  \O\" Is for Outlaw"            105   236283  0805059555      10
# 72221  \O\" Is for Outlaw"            105   238120  0805059555       0
# 72222  \O\" Is for Outlaw"            105   254899  0805059555       0
#
#                 author  year                 Publisher  \
# 0      Debbie Macomber  2001                      Mira
# 1      Debbie Macomber  2001                      Mira
# 2      Debbie Macomber  2001                      Mira
# 3      Debbie Macomber  2001                      Mira
# 4      Debbie Macomber  2001                      Mira
# ...                ...   ...                       ...
# 72218      Sue Grafton  1999  Henry Holt &amp; Company
# 72219      Sue Grafton  1999  Henry Holt &amp; Company
# 72220      Sue Grafton  1999  Henry Holt &amp; Company
# 72221      Sue Grafton  1999  Henry Holt &amp; Company
# 72222      Sue Grafton  1999  Henry Holt &amp; Company
#
#                                                Image_URL
# 0      http://images.amazon.com/images/P/1551668300.0...
# 1      http://images.amazon.com/images/P/1551668300.0...
# 2      http://images.amazon.com/images/P/1551668300.0...
# 3      http://images.amazon.com/images/P/1551668300.0...
# 4      http://images.amazon.com/images/P/1551668300.0...
# ...                                                  ...
# 72218  http://images.amazon.com/images/P/0805059555.0...
# 72219  http://images.amazon.com/images/P/0805059555.0...
# 72220  http://images.amazon.com/images/P/0805059555.0...
# 72221  http://images.amazon.com/images/P/0805059555.0...
# 72222  http://images.amazon.com/images/P/0805059555.0...
#
# [72223 rows x 9 columns]

# %%
############################

# %%
# # merge ratings and books
# ratings_with_books = ratings.merge(books, on='ISBN', how='inner')

# %%
# ratings_with_books
# Out:
#         user_id        ISBN  rating  \
# 0        277427  002542730X      10
# 1          3363  002542730X       0
# 2         11676  002542730X       6
# 3         12538  002542730X      10
# 4         13552  002542730X       0
# ...         ...         ...     ...
# 487666   275970  1892145022       0
# 487667   275970  1931868123       0
# 487668   275970  3411086211      10
# 487669   275970  3829021860       0
# 487670   275970  4770019572       0
#
#                                                     title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 1       Politically Correct Bedtime Stories: Modern Ta...
# 2       Politically Correct Bedtime Stories: Modern Ta...
# 3       Politically Correct Bedtime Stories: Modern Ta...
# 4       Politically Correct Bedtime Stories: Modern Ta...
# ...                                                   ...
# 487666                                   Here Is New York
# 487667  There's a Porcupine in My Outhouse: Misadventu...
# 487668                                         Die Biene.
# 487669                                     The Penis Book
# 487670                                            Musashi
#
#                                author  year  \
# 0                   James Finn Garner  1994
# 1                   James Finn Garner  1994
# 2                   James Finn Garner  1994
# 3                   James Finn Garner  1994
# 4                   James Finn Garner  1994
# ...                               ...   ...
# 487666                    E. B. White  1999
# 487667                   Mike Tougias  2002
# 487668  Sybil GrÃ?Â¤fin SchÃ?Â¶nfeldt  1993
# 487669                   Joseph Cohen  1999
# 487670                 Eiji Yoshikawa  1995
#
#                                    Publisher  \
# 0                  John Wiley &amp; Sons Inc
# 1                  John Wiley &amp; Sons Inc
# 2                  John Wiley &amp; Sons Inc
# 3                  John Wiley &amp; Sons Inc
# 4                  John Wiley &amp; Sons Inc
# ...                                      ...
# 487666                       Little Bookroom
# 487667                    Capital Books (VA)
# 487668  Bibliographisches Institut, Mannheim
# 487669                              Konemann
# 487670          Kodansha International (JPN)
#
#                                                 Image_URL
# 0       http://images.amazon.com/images/P/002542730X.0...
# 1       http://images.amazon.com/images/P/002542730X.0...
# 2       http://images.amazon.com/images/P/002542730X.0...
# 3       http://images.amazon.com/images/P/002542730X.0...
# 4       http://images.amazon.com/images/P/002542730X.0...
# ...                                                   ...
# 487666  http://images.amazon.com/images/P/1892145022.0...
# 487667  http://images.amazon.com/images/P/1931868123.0...
# 487668  http://images.amazon.com/images/P/3411086211.0...
# 487669  http://images.amazon.com/images/P/3829021860.0...
# 487670  http://images.amazon.com/images/P/4770019572.0...
#
# [487671 rows x 8 columns]

# %%
# raing_countBy_books = ratings_with_books.groupby('title')['rating'].count().reset_index()

# %%
# raing_countBy_books.rename(columns={
#     'rating':'num_of_rating'
# }, inplace=True)

# %%
# # this is the num of rating by books
# raing_countBy_books.head()
# Out:
#                                                title  num_of_rating
# 0   A Light in the Storm: The Civil War Diary of ...              2
# 1                              Always Have Popsicles              1
# 2               Apple Magic (The Collector's series)              1
# 3   Beyond IBM: Leadership Marketing and Finance ...              1
# 4   Clifford Visita El Hospital (Clifford El Gran...              1

# %%
# final_rating = raing_countBy_books.merge(ratings_with_books, on='title')

# %%
# # this is the final rating dataframe contain num of rating
# final_rating.head()
# Out:
#                                                title  num_of_rating  user_id  \
# 0   A Light in the Storm: The Civil War Diary of ...              2    35859
# 1   A Light in the Storm: The Civil War Diary of ...              2    96448
# 2                              Always Have Popsicles              1   172742
# 3               Apple Magic (The Collector's series)              1   198711
# 4   Beyond IBM: Leadership Marketing and Finance ...              1    11601
#
#          ISBN  rating            author  year                    Publisher  \
# 0  0590567330       0       Karen Hesse  1999  Hyperion Books for Children
# 1  0590567330       9       Karen Hesse  1999  Hyperion Books for Children
# 2  0964147726       0    Rebecca Harvin  1994            Rebecca L. Harvin
# 3  0942320093       0  Martina Boudreau  1984           Amer Cooking Guild
# 4  0962295701       0        Lou Mobley  1989       Teleonet, Incorporated
#
#                                            Image_URL
# 0  http://images.amazon.com/images/P/0590567330.0...
# 1  http://images.amazon.com/images/P/0590567330.0...
# 2  http://images.amazon.com/images/P/0964147726.0...
# 3  http://images.amazon.com/images/P/0942320093.0...
# 4  http://images.amazon.com/images/P/0962295701.0...

# %%
# # Flieter rating, select num of rating greater than 30
# final_rating= final_rating[final_rating['num_of_rating']>30]

# %%
# final_rating.shape
# Out:
# (96548, 9)

# %%
# final_rating.drop_duplicates(subset=['title','user_id'], inplace=True)

# %%
# # this is the final Rating after data Cleaning 
# final_rating
# Out:
#                       title  num_of_rating  user_id        ISBN  rating  \
# 290          10 Lb. Penalty             35    39281  0515123471       0
# 291          10 Lb. Penalty             35    49109  0515123471       5
# 292          10 Lb. Penalty             35    69405  0515123471       0
# 293          10 Lb. Penalty             35    76352  0515123471       0
# 294          10 Lb. Penalty             35    83287  0515123471      10
# ...                     ...            ...      ...         ...     ...
# 487432  \O\" Is for Outlaw"            105   234359  0805059555       0
# 487433  \O\" Is for Outlaw"            105   234623  0805059555       0
# 487434  \O\" Is for Outlaw"            105   236283  0805059555      10
# 487435  \O\" Is for Outlaw"            105   238120  0805059555       0
# 487436  \O\" Is for Outlaw"            105   254899  0805059555       0
#
#               author  year                 Publisher  \
# 290     Dick Francis  1998                Jove Books
# 291     Dick Francis  1998                Jove Books
# 292     Dick Francis  1998                Jove Books
# 293     Dick Francis  1998                Jove Books
# 294     Dick Francis  1998                Jove Books
# ...              ...   ...                       ...
# 487432   Sue Grafton  1999  Henry Holt &amp; Company
# 487433   Sue Grafton  1999  Henry Holt &amp; Company
# 487434   Sue Grafton  1999  Henry Holt &amp; Company
# 487435   Sue Grafton  1999  Henry Holt &amp; Company
# 487436   Sue Grafton  1999  Henry Holt &amp; Company
#
#                                                 Image_URL
# 290     http://images.amazon.com/images/P/0515123471.0...
# 291     http://images.amazon.com/images/P/0515123471.0...
# 292     http://images.amazon.com/images/P/0515123471.0...
# 293     http://images.amazon.com/images/P/0515123471.0...
# 294     http://images.amazon.com/images/P/0515123471.0...
# ...                                                   ...
# 487432  http://images.amazon.com/images/P/0805059555.0...
# 487433  http://images.amazon.com/images/P/0805059555.0...
# 487434  http://images.amazon.com/images/P/0805059555.0...
# 487435  http://images.amazon.com/images/P/0805059555.0...
# 487436  http://images.amazon.com/images/P/0805059555.0...
#
# [93858 rows x 9 columns]

# %% [markdown]
# ## Feature engineering

# %%
pivot = final_rating.pivot_table(columns='user_id', index='title', values='rating')

# %%
pivot.fillna(0, inplace=True)

# %%
pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             2977    3363    4017    \
# title
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             4385    6242    6251    \
# title
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     7.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             6323    ...  274004  \
# title                                                       ...
# 16 Lighthouse Road                                     0.0  ...     0.0
# 1984                                                   0.0  ...     0.0
# 1st to Die: A Novel                                    0.0  ...     0.0
# 2010: Odyssey Two                                      0.0  ...     0.0
# 204 Rosewood Lane                                      0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# user_id                                             274061  274301  274308  \
# title
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     8.0     0.0
#
# user_id                                             274808  275970  277427  \
# title
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             277478  277639  278418
# title
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [1259 rows x 886 columns]

# %%
# fix 0 in the datasets
book_sparse = csr_matrix(pivot)

# %%
book_sparse
# Out:
# <1259x886 sparse matrix of type '<class 'numpy.float64'>'
# 	with 17141 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Data Modeling

# %%
model = NearestNeighbors(algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
# find the 6 cloested distance of 6 neigbors(include itself)
distance, suggestion = model.kneighbors(pivot.iloc[1].values.reshape(1,-1), n_neighbors=6)

# %%
distance
# Out:
# array([[ 0.        , 42.09513036, 43.        , 43.03486958, 43.12771731,
#         43.16248371]])

# %%
suggestion
# Out:
# array([[  1, 610, 533, 872, 364,  52]], dtype=int64)

# %%
suggestion.shape
# Out:
# (1, 6)

# %%
# This is the 5 books that are recommended to 16 Lighthouse Road
for i in range(len(suggestion[0])):
    print(pivot.index[suggestion[0][i]])
# Out:
# 1984
# No Safe Place
# Malice
# The Bookman's Wake (Cliff Janeway Novels (Paperback))
# Gates of Paradise
# AGE OF INNOCENCE (MOVIE TIE-IN)

# %%
books_name = pivot.index

# %%
# Here is all the bookname
books_name
# Out:
# Index(['16 Lighthouse Road', '1984', '1st to Die: A Novel',
#        '2010: Odyssey Two', '204 Rosewood Lane', '24 Hours', '2nd Chance',
#        '4 Blondes',
#        'A 2nd Helping of Chicken Soup for the Soul (Chicken Soup for the Soul Series (Paper))',
#        'A Beautiful Mind: The Life of Mathematical Genius and Nobel Laureate John Nash',
#        ...
#        'Without Remorse',
#        'Witness in Death (Eve Dallas Mysteries (Paperback))',
#        'Women Who Run with the Wolves',
#        'Word Freak: Heartbreak, Triumph, Genius, and Obsession in the World of Competitive Scrabble Players',
#        'Wuthering Heights', 'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='title', length=1259)

# %%
# creat the recommendation system

def recommend_book(book_name):
    book_id = np.where(pivot.index == book_name)[0][0]
    distance, suggestion = model.kneighbors(pivot.iloc[book_id].values.reshape(1,-1), n_neighbors=6)
    for i in range(len(suggestion[0])):
        print(pivot.index[suggestion[0][i]])

# %%
# testing 
recommend_book("Harry Potter and the Sorcerer's Stone (Book 1)")
# Out:
# Harry Potter and the Sorcerer's Stone (Book 1)
# The Mammoth Hunters (Auel, Jean M. , Earth's Children.)
# The Charm School
# Eaters of the Dead
# Fortune's Hand
# The List

# %%
# # testing 
# recommend_book('You Belong To Me')
# Out:
# You Belong To Me
# The Cradle Will Fall
# Exclusive
# Loves Music, Loves to Dance
# The Anastasia Syndrome
# Gates of Paradise

# %%
##################

# %%
user_merge_ratings = final_rating.merge(users, on='user_id')
user_merge_ratings.head()
# Out:
#                  title  num_of_rating  user_id        ISBN  rating  \
# 0   16 Lighthouse Road             38    11676  1551668300       0
# 1                 1984             52    11676  0451524934       0
# 2  1st to Die: A Novel            162    11676  0446610038      10
# 3  1st to Die: A Novel            162    11676  0316666009       8
# 4    204 Rosewood Lane             40    11676  1551669293       0
#
#             author  year                 Publisher  \
# 0  Debbie Macomber  2001                      Mira
# 1    George Orwell  1990               Signet Book
# 2  James Patterson  2002             Warner Vision
# 3  James Patterson  2001  Little Brown and Company
# 4  Debbie Macomber  2002                      Mira
#
#                                            Image_URL       Location country  \
# 0  http://images.amazon.com/images/P/1551668300.0...  n/a, n/a, n/a     n/a
# 1  http://images.amazon.com/images/P/0451524934.0...  n/a, n/a, n/a     n/a
# 2  http://images.amazon.com/images/P/0446610038.0...  n/a, n/a, n/a     n/a
# 3  http://images.amazon.com/images/P/0316666009.0...  n/a, n/a, n/a     n/a
# 4  http://images.amazon.com/images/P/1551669293.0...  n/a, n/a, n/a     n/a
#
#   city  Age
# 0  n/a  NaN
# 1  n/a  NaN
# 2  n/a  NaN
# 3  n/a  NaN
# 4  n/a  NaN

# %%
def clean_us(country):
    if country == 'us':
        return 'usa'
    else:
        return country

# %%
user_merge_ratings['country'] = user_merge_ratings['country'].apply(clean_us)

# %%
user_merge_ratings.head()
# Out:
#                  title  num_of_rating  user_id        ISBN  rating  \
# 0   16 Lighthouse Road             38    11676  1551668300       0
# 1                 1984             52    11676  0451524934       0
# 2  1st to Die: A Novel            162    11676  0446610038      10
# 3  1st to Die: A Novel            162    11676  0316666009       8
# 4    204 Rosewood Lane             40    11676  1551669293       0
#
#             author  year                 Publisher  \
# 0  Debbie Macomber  2001                      Mira
# 1    George Orwell  1990               Signet Book
# 2  James Patterson  2002             Warner Vision
# 3  James Patterson  2001  Little Brown and Company
# 4  Debbie Macomber  2002                      Mira
#
#                                            Image_URL       Location country  \
# 0  http://images.amazon.com/images/P/1551668300.0...  n/a, n/a, n/a     n/a
# 1  http://images.amazon.com/images/P/0451524934.0...  n/a, n/a, n/a     n/a
# 2  http://images.amazon.com/images/P/0446610038.0...  n/a, n/a, n/a     n/a
# 3  http://images.amazon.com/images/P/0316666009.0...  n/a, n/a, n/a     n/a
# 4  http://images.amazon.com/images/P/1551669293.0...  n/a, n/a, n/a     n/a
#
#   city  Age
# 0  n/a  NaN
# 1  n/a  NaN
# 2  n/a  NaN
# 3  n/a  NaN
# 4  n/a  NaN

# %%
user_merge_ratings.groupby(['country'])['num_of_rating'].sum().sort_values(ascending=False)
# Out:
# country
# usa                   4693341
# canada                 463380
# united kingdom         110408
# n/a                     68678
# australia               60672
# portugal                44315
#                         36065
# new zealand             24917
# malaysia                24279
# germany                 19892
# spain                   15937
# netherlands             14812
# iran                     9918
# france                   7830
# china                    7206
# italy                    6724
# brazil                   6154
# romania                  5728
# qatar                    3688
# belgium                  3304
# switzerland              3273
# dominican republic       2479
# austria                  1785
# japan                    1664
# finland                  1398
# sweden                   1223
# denmark                   345
# Name: num_of_rating, dtype: int64

# %%
region_unique = user_merge_ratings['country'].unique().tolist()

# %%
region_unique.remove('')
region_unique.remove('n/a')

# %%
region_unique
# Out:
# ['usa',
#  'canada',
#  'portugal',
#  'united kingdom',
#  'denmark',
#  'spain',
#  'australia',
#  'brazil',
#  'malaysia',
#  'germany',
#  'netherlands',
#  'iran',
#  'china',
#  'austria',
#  'italy',
#  'qatar',
#  'sweden',
#  'new zealand',
#  'france',
#  'belgium',
#  'romania',
#  'finland',
#  'switzerland',
#  'japan',
#  'dominican republic']

# %%
with open('../py_objects/region_unique.pkl', 'wb') as file:
    pickle.dump(region_unique, file)

# %%
# store the saved dataframe
user_merge_ratings.to_csv('../data/final_merge_table.csv', index=False)

# %%
#######################################

# %%
# This is important
pivot.to_csv('../py_objects/pivot.csv', index=True)

# %%
# this is important
final_rating.to_csv('../py_objects/final_rating.csv', index=True)

# %%
# Save model and python object
with open('../py_objects/model.pkl', 'wb') as file:
    pickle.dump(model, file)

with open('../py_objects/books_name.pkl', 'wb') as file:
    pickle.dump(books_name, file)

with open('../py_objects/final_rating.pkl', 'wb') as file:
    pickle.dump(final_rating, file)

with open('../py_objects/pivot.pkl', 'wb') as file:
    pickle.dump(pivot, file)
